# %% [markdown]
# <a href="https://colab.research.google.com/github/ivethsg/Probabilidad-/blob/main/Distribucion_Normal/problema1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm

# %%
media = 70
desv_std=4
num_datos=500

datos= np.random.normal(media, desv_std, num_datos)
datos[0:50]
# Out:
# array([72.82172786, 64.63654346, 70.87909579, 68.00460034, 77.37400221,
#        74.93877177, 63.4718104 , 68.32892465, 66.48435581, 69.27489339,
#        65.46364911, 64.06710699, 66.53167856, 64.73858188, 68.83292743,
#        67.65149053, 64.98174513, 60.20230004, 65.79380496, 78.31523825,
#        74.53705507, 69.74837679, 65.19627634, 72.79072294, 72.7405259 ,
#        73.16872448, 75.57335479, 63.39188281, 66.8215775 , 67.29067597,
#        66.8066858 , 75.42934816, 64.51638374, 71.64526487, 70.09194423,
#        70.19024685, 68.34993773, 71.65509723, 68.45144544, 70.87013792,
#        71.25186554, 73.74328786, 80.55280367, 73.17510116, 71.400037  ,
#        75.71120132, 75.05488983, 67.28579562, 74.05327131, 70.20350797])

# %%
x=np.linspace(media-3 * desv_std, media + 3* desv_std, num_datos)
pdf=1 / (desv_std* np.sqrt(2*np.pi))* np.exp(-(x-media)**2)/(2*desv_std**2)

print("Imprimir los primeros 50 valores de x", x [0:50], ",y los primeros 50 valores de pdf", pdf[0:50])
# Out:
# Imprimir los primeros 50 valores de x [58.         58.04809619 58.09619238 58.14428858 58.19238477 58.24048096
#  58.28857715 58.33667335 58.38476954 58.43286573 58.48096192 58.52905812
#  58.57715431 58.6252505  58.67334669 58.72144289 58.76953908 58.81763527
#  58.86573146 58.91382766 58.96192385 59.01002004 59.05811623 59.10621242
#  59.15430862 59.20240481 59.250501   59.29859719 59.34669339 59.39478958
#  59.44288577 59.49098196 59.53907816 59.58717435 59.63527054 59.68336673
#  59.73146293 59.77955912 59.82765531 59.8757515  59.9238477  59.97194389
#  60.02004008 60.06813627 60.11623246 60.16432866 60.21242485 60.26052104
#  60.30861723 60.35671343] ,y los primeros 50 valores de pdf [9.02183130e-66 2.85495940e-65 8.99282023e-65 2.81956837e-64
#  8.79954243e-64 2.73355799e-63 8.45254003e-63 2.60157842e-62
#  7.97034922e-62 2.43057217e-61 7.37786038e-61 2.22916947e-60
#  6.70419261e-60 2.00696880e-59 5.98033485e-59 1.77378560e-58
#  5.23681809e-58 1.53895030e-57 4.50165744e-57 1.31072334e-56
#  3.79874697e-56 1.09587354e-55 3.14681533e-55 8.99441280e-55
#  2.55896954e-54 7.24683143e-54 2.04278163e-53 5.73173985e-53
#  1.60081719e-52 4.45028424e-52 1.23147189e-51 3.39196996e-51
#  9.29972775e-51 2.53792751e-50 6.89412153e-50 1.86410082e-49
#  5.01707511e-49 1.34407205e-48 3.58414226e-48 9.51346380e-48
#  2.51352288e-47 6.61024808e-47 1.73038769e-46 4.50878799e-46
#  1.16941041e-45 3.01901200e-45 7.75806591e-45 1.98441651e-44
#  5.05246067e-44 1.28045345e-43]

# %%
plt.figure(figsize=(6,4))
plt.hist(datos, bins=15, alpha=0.4, color='b')
plt.title('Distribución normal')
plt.xlabel('Peso en kg de los estudiantes')
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(6,4))
plt.plot(x, pdf, label= 'Normal: (media:{}; ds:{})'.format(np.round(media,2), np.round(desv_std)))
plt.title('Función de densidad de probabilidad(PDF)- Distribución Normal')
plt.xlabel('Peso en kg de los estudiantes')
plt.ylabel('Densidad de Probabilidad')
plt.legend()
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(6,4))
plt.hist(datos, bins=15, alpha=0.4, density=True, color='b')
plt.plot(x, pdf, 'k', linewidth=2)

plt.title('Distribución normal')
plt.xlabel('Peso en kg de los estudiantes')
plt.grid(True)
plt.show()
