# %% [markdown]
# <a href="https://colab.research.google.com/github/ivethsg/Probabilidad-/blob/main/probabilidad_U2_Programa1_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import math as mt
from itertools import combinations
from itertools import combinations_with_replacement
import numpy as np

# %%
nombres = ["Oscar", "Paco", "Paty", "Laura", "Rubén", "Luis", "Lucy", "Alberto", "Juan", "Danny"]
n = len (nombres)
r = 2
Cn = mt. factorial(n) / (mt.factorial(r) * mt.factorial(n-r))
" posibles combinaciones sin repetición del total de ",
print("Aquí las combinaciones")
combinaciones_nombres = list(combinations (nombres, r))

for combinacion in combinaciones_nombres:
    print (combinacion)
# Out:
# Aquí las combinaciones
# ('Oscar', 'Paco')
# ('Oscar', 'Paty')
# ('Oscar', 'Laura')
# ('Oscar', 'Rubén')
# ('Oscar', 'Luis')
# ('Oscar', 'Lucy')
# ('Oscar', 'Alberto')
# ('Oscar', 'Juan')
# ('Oscar', 'Danny')
# ('Paco', 'Paty')
# ('Paco', 'Laura')
# ('Paco', 'Rubén')
# ('Paco', 'Luis')
# ('Paco', 'Lucy')
# ('Paco', 'Alberto')
# ('Paco', 'Juan')
# ('Paco', 'Danny')
# ('Paty', 'Laura')
# ('Paty', 'Rubén')
# ('Paty', 'Luis')
# ('Paty', 'Lucy')
# ('Paty', 'Alberto')
# ('Paty', 'Juan')
# ('Paty', 'Danny')
# ('Laura', 'Rubén')
# ('Laura', 'Luis')
# ('Laura', 'Lucy')
# ('Laura', 'Alberto')
# ('Laura', 'Juan')
# ('Laura', 'Danny')
# ('Rubén', 'Luis')
# ('Rubén', 'Lucy')
# ('Rubén', 'Alberto')
# ('Rubén', 'Juan')
# ('Rubén', 'Danny')
# ('Luis', 'Lucy')
# ('Luis', 'Alberto')
# ('Luis', 'Juan')
# ('Luis', 'Danny')
# ('Lucy', 'Alberto')
# ('Lucy', 'Juan')
# ('Lucy', 'Danny')
# ('Alberto', 'Juan')
# ('Alberto', 'Danny')
# ('Juan', 'Danny')
