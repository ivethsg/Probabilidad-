# %% [markdown]
# <a href="https://colab.research.google.com/github/ivethsg/Probabilidad-/blob/main/Unidad%201/Pr%C3%A1ctica_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Probabilidad y estadistica
# ## Unidad 1
# ### Facilitador: Jose Gabriel Rodriguez Rivas
# ### Alumno: Iveth Esperanza Santacruz Guerrero
# ### **Programa 1: Estadística básica e histogramas**

# %%
from statistics import *

# %%
grupoa= [70,70,65,90,100,95, 45, 80, 73, 20, 100, 96]
print(grupoa)
# Out:
# [70, 70, 65, 90, 100, 95, 45, 80, 73, 20, 100, 96]

# %%
type(grupoa)
# Out:
# list

# %%
promedio= sum(grupoa)/len(grupoa)
print(promedio)
# Out:
# 75.33333333333333

# %%
promedio2=mean(grupoa)
print(promedio)
# Out:
# 75.33333333333333
