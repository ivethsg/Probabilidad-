# %% [markdown]
# <a href="https://colab.research.google.com/github/ivethsg/Probabilidad-/blob/main/Unidad%201/Practica_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Probabilidad y estadistica
# ## Unidad 1
# ### Facilitador: Jose Gabriel Rodriguez Rivas
# ### Alumno: Iveth Esperanza Santacruz Guerrero
# ### **Práctica 2: Máximo, minimo, Rango y dispersión de datos**

# %%
import random
import matplotlib.pyplot as plt
from statistics import*

# %%
fabrica1= []
for i in range(100):
  numeroaleatorio=round(random.uniform(50, 100),2)
  fabrica1.append(numeroaleatorio)
print(fabrica1)
# Out:
# [58.3, 74.74, 63.16, 57.03, 93.72, 65.92, 89.42, 60.62, 72.49, 99.57, 64.65, 78.24, 50.85, 65.86, 82.06, 53.56, 90.9, 77.02, 62.7, 94.13, 79.47, 54.76, 68.25, 83.6, 56.09, 55.89, 84.31, 79.72, 88.66, 88.81, 52.57, 76.84, 70.74, 75.22, 87.48, 71.23, 85.89, 87.5, 58.45, 96.56, 87.36, 56.1, 53.61, 56.64, 70.06, 59.89, 89.93, 99.82, 95.88, 74.49, 83.98, 59.41, 77.91, 81.16, 63.88, 65.46, 76.56, 96.26, 89.55, 97.57, 56.17, 56.93, 50.74, 73.29, 71.75, 78.97, 74.86, 82.13, 61.67, 69.76, 84.3, 50.98, 77.21, 60.03, 74.84, 87.6, 65.49, 97.47, 96.57, 50.56, 59.03, 87.41, 96.26, 63.07, 65.55, 82.57, 62.6, 88.3, 74.32, 78.11, 87.91, 75.74, 84.77, 59.06, 85.52, 64.28, 54.49, 86.49, 95.48, 51.95]

# %%
fabrica2= []
for i in range(100):
  numeroaleatorio=round(random.uniform(50, 100),2)
  fabrica2.append(numeroaleatorio)
print(fabrica2)
# Out:
# [67.59, 83.65, 64.3, 56.07, 61.44, 73.47, 79.71, 71.9, 82.89, 99.16, 82.08, 95.85, 77.04, 81.94, 60.49, 50.14, 84.1, 98.65, 95.97, 70.0, 82.01, 69.27, 52.97, 52.31, 89.85, 84.24, 62.33, 71.95, 67.81, 61.27, 97.65, 95.77, 78.59, 83.62, 81.76, 60.24, 94.34, 72.37, 82.2, 52.1, 58.81, 81.33, 90.12, 80.19, 69.4, 70.28, 76.91, 57.0, 89.3, 79.52, 95.3, 92.47, 83.43, 67.79, 75.71, 94.31, 83.27, 59.15, 59.28, 69.07, 83.87, 89.13, 70.2, 69.19, 64.95, 79.14, 95.15, 97.37, 82.23, 81.43, 84.48, 96.76, 63.81, 83.85, 69.75, 99.8, 94.97, 75.95, 92.78, 63.38, 86.69, 76.91, 89.1, 75.11, 80.06, 56.23, 95.99, 93.31, 55.48, 85.33, 77.12, 84.35, 93.38, 57.77, 76.05, 50.88, 81.98, 79.69, 71.99, 89.34]

# %%
maximo1= max(fabrica1)
minimo1= min(fabrica1)
rango1= maximo1-minimo1
media1= mean(fabrica1)
mediana1= median(fabrica1)
moda1= mode(fabrica1)
desviacion_estandar_fabrica1=stdev(fabrica1)
print("Estadistica descriptiva de la Fabrica \n", "Media=", media1, "\n Mediana=", mediana1, "\n Moda=", moda1, "Maximo=", maximo1, "\n Minimo=", minimo1, "\n Rango=", rango1)
print(desviacion_estandar_fabrica1)
# Out:
# Estadistica descriptiva de la Fabrica
#  Media= 74.1673
#  Mediana= 74.85
#  Moda= 96.26 Maximo= 99.82
#  Minimo= 50.56
#  Rango= 49.25999999999999
# 14.304803661283813

# %%
maximo2= max(fabrica2)
minimo2= min(fabrica2)
rango2= maximo2-minimo2
media2= mean(fabrica2)
mediana2= median(fabrica2)
moda2= mode(fabrica2)
desviacion_estandar_fabrica2=stdev(fabrica2)
print("Estadistica descriptiva de la Fabrica \n", "Media=", media2, "\n Mediana=", mediana2, "\n Moda=", moda2, "Maximo=", maximo2, "\n Minimo=", minimo2, "\n Rango=", rango2)
print(desviacion_estandar_fabrica2)
# Out:
# Estadistica descriptiva de la Fabrica
#  Media= 77.5668
#  Mediana= 79.69999999999999
#  Moda= 76.91 Maximo= 99.8
#  Minimo= 50.14
#  Rango= 49.66
# 13.333146277475757

# %%
plt.figure(figsize = (8,6))
plt.hist(fabrica1, bins=10, alpha=0.2, color='b', edgecolor = "black")
plt.axvline(media1, color='b', linestyle='dashed', linewidth=2, label=f'Media={media1:.2f}')
plt.axvline(mediana1, color='r', linestyle='dashed', linewidth=2, label=f'Mediana={mediana1:.2f}')
plt.axvline(moda1, color='y', linestyle='dashed', linewidth=2, label=f'Moda={moda1:.2f}')
plt.axvline(media1 - desviacion_estandar_fabrica1, color='black', linestyle='dashed', linewidth=2, label=f'Desv. Estándar={desviacion_estandar_fabrica1:.2f}')
plt.axvline(media1 + desviacion_estandar_fabrica1, color='black', linestyle='dashed', linewidth=2)

plt.xlabel('Valor')
plt.ylabel('Frecuencia')
plt.title("Producción diaria de la fabrica 1")
plt.legend()
plt.show()

# %%
plt.figure(figsize = (8,6))
plt.hist(fabrica1, bins=10, alpha=0.2, color='b', edgecolor = "black")
plt.axvline(media2, color='b', linestyle='dashed', linewidth=2, label=f'Media={media2:.2f}')
plt.axvline(mediana2, color='r', linestyle='dashed', linewidth=2, label=f'Mediana={mediana2:.2f}')
plt.axvline(moda2, color='y', linestyle='dashed', linewidth=2, label=f'Moda={moda2:.2f}')
plt.axvline(media2 - desviacion_estandar_fabrica2, color='black', linestyle='dashed', linewidth=2, label=f'Desv. Estándar={desviacion_estandar_fabrica2:.2f}')
plt.axvline(media2 + desviacion_estandar_fabrica1, color='black', linestyle='dashed', linewidth=2)

plt.xlabel('Valor')
plt.ylabel('Frecuencia')
plt.title("Producción diaria de la fabrica 2")
plt.legend()
plt.show()

# %%
import seaborn as sns

# %%
sns.histplot(x= fabrica1, kde= True, kde_kws={'bw_adjust': 0.5}, bins= 10)
# Out:
# <Axes: ylabel='Count'>
