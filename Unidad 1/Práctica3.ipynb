# %% [markdown]
# <a href="https://colab.research.google.com/github/ivethsg/Probabilidad-/blob/main/Unidad%201/Pr%C3%A1ctica3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Probabilidad y estadistica
# ## Unidad 1
# ### Facilitador: Jose Gabriel Rodriguez Rivas
# ### Alumno: Iveth Esperanza Santacruz Guerrero
# ### **Práctica 3: Tablas de frecuencias**

# %%
import random
edades=[]
for i in range(100):
  numeroaleatorio= random.randint(18,70)
  edades.append(numeroaleatorio)
print(edades)
# Out:
# [46, 27, 60, 18, 65, 50, 56, 55, 62, 58, 19, 54, 20, 45, 40, 48, 57, 26, 21, 21, 22, 20, 70, 19, 40, 68, 27, 35, 69, 38, 54, 66, 24, 49, 61, 50, 51, 26, 60, 27, 29, 45, 65, 23, 58, 44, 22, 32, 56, 20, 35, 22, 39, 38, 45, 62, 28, 61, 30, 42, 26, 43, 43, 41, 70, 40, 45, 55, 55, 37, 20, 67, 48, 63, 36, 68, 20, 69, 65, 23, 69, 53, 46, 70, 28, 21, 60, 28, 31, 61, 20, 32, 65, 56, 18, 30, 52, 56, 67, 25]

# %%
import pandas as pd

# %%
df=pd.DataFrame(edades, columns=['Edad'])
df.head()
# Out:
#    Edad
# 0    46
# 1    27
# 2    60
# 3    18
# 4    65

# %%
tabla_frecuencias= df['Edad'].value_counts().reset_index()
tabla_frecuencias.columns=['Edad', 'Frecuencia']
tabla_frecuencias= tabla_frecuencias.sort_values(by='Edad')

print("Tabla de Distribución de Frecuencias:")
tabla_frecuencias
# Out:
# Tabla de Distribución de Frecuencias:
#     Edad  Frecuencia
# 22    18           2
# 18    19           2
# 0     20           6
# 12    21           3
# 13    22           3
# 24    23           2
# 34    24           1
# 47    25           1
# 14    26           3
# 6     27           3
# 9     28           3
# 32    29           1
# 28    30           2
# 45    31           1
# 26    32           2
# 23    35           2
# 43    36           1
# 41    37           1
# 25    38           2
# 37    39           1
# 5     40           3
# 40    41           1
# 38    42           1
# 29    43           2
# 39    44           1
# 2     45           4
# 21    46           2
# 16    48           2
# 35    49           1
# 15    50           2
# 33    51           1
# 46    52           1
# 44    53           1
# 19    54           2
# 4     55           3
# 1     56           4
# 31    57           1
# 17    58           2
# 7     60           3
# 10    61           3
# 20    62           2
# 42    63           1
# 3     65           4
# 36    66           1
# 27    67           2
# 30    68           2
# 11    69           3
# 8     70           3

# %%
tabla_frecuencias['Frecuencia Relativa']= tabla_frecuencias['Frecuencia']/100
tabla_frecuencias
# Out:
#     Edad  Frecuencia  Frecuencia Relativa
# 22    18           2                 0.02
# 18    19           2                 0.02
# 0     20           6                 0.06
# 12    21           3                 0.03
# 13    22           3                 0.03
# 24    23           2                 0.02
# 34    24           1                 0.01
# 47    25           1                 0.01
# 14    26           3                 0.03
# 6     27           3                 0.03
# 9     28           3                 0.03
# 32    29           1                 0.01
# 28    30           2                 0.02
# 45    31           1                 0.01
# 26    32           2                 0.02
# 23    35           2                 0.02
# 43    36           1                 0.01
# 41    37           1                 0.01
# 25    38           2                 0.02
# 37    39           1                 0.01
# 5     40           3                 0.03
# 40    41           1                 0.01
# 38    42           1                 0.01
# 29    43           2                 0.02
# 39    44           1                 0.01
# 2     45           4                 0.04
# 21    46           2                 0.02
# 16    48           2                 0.02
# 35    49           1                 0.01
# 15    50           2                 0.02
# 33    51           1                 0.01
# 46    52           1                 0.01
# 44    53           1                 0.01
# 19    54           2                 0.02
# 4     55           3                 0.03
# 1     56           4                 0.04
# 31    57           1                 0.01
# 17    58           2                 0.02
# 7     60           3                 0.03
# 10    61           3                 0.03
# 20    62           2                 0.02
# 42    63           1                 0.01
# 3     65           4                 0.04
# 36    66           1                 0.01
# 27    67           2                 0.02
# 30    68           2                 0.02
# 11    69           3                 0.03
# 8     70           3                 0.03

# %%
tabla_frecuencias['Frec Porcentual']= tabla_frecuencias['Frecuencia']/ 100*100
tabla_frecuencias
# Out:
#     Edad  Frecuencia  Frecuencia Relativa  Frec. Porcentual
# 22    18           2                 0.02               2.0
# 18    19           2                 0.02               2.0
# 0     20           6                 0.06               6.0
# 12    21           3                 0.03               3.0
# 13    22           3                 0.03               3.0
# 24    23           2                 0.02               2.0
# 34    24           1                 0.01               1.0
# 47    25           1                 0.01               1.0
# 14    26           3                 0.03               3.0
# 6     27           3                 0.03               3.0
# 9     28           3                 0.03               3.0
# 32    29           1                 0.01               1.0
# 28    30           2                 0.02               2.0
# 45    31           1                 0.01               1.0
# 26    32           2                 0.02               2.0
# 23    35           2                 0.02               2.0
# 43    36           1                 0.01               1.0
# 41    37           1                 0.01               1.0
# 25    38           2                 0.02               2.0
# 37    39           1                 0.01               1.0
# 5     40           3                 0.03               3.0
# 40    41           1                 0.01               1.0
# 38    42           1                 0.01               1.0
# 29    43           2                 0.02               2.0
# 39    44           1                 0.01               1.0
# 2     45           4                 0.04               4.0
# 21    46           2                 0.02               2.0
# 16    48           2                 0.02               2.0
# 35    49           1                 0.01               1.0
# 15    50           2                 0.02               2.0
# 33    51           1                 0.01               1.0
# 46    52           1                 0.01               1.0
# 44    53           1                 0.01               1.0
# 19    54           2                 0.02               2.0
# 4     55           3                 0.03               3.0
# 1     56           4                 0.04               4.0
# 31    57           1                 0.01               1.0
# 17    58           2                 0.02               2.0
# 7     60           3                 0.03               3.0
# 10    61           3                 0.03               3.0
# 20    62           2                 0.02               2.0
# 42    63           1                 0.01               1.0
# 3     65           4                 0.04               4.0
# 36    66           1                 0.01               1.0
# 27    67           2                 0.02               2.0
# 30    68           2                 0.02               2.0
# 11    69           3                 0.03               3.0
# 8     70           3                 0.03               3.0

# %%
tabla_frecuencias['Frec Acumulada'] = tabla_frecuencias ['Frecuencia'].cumsum()
tabla_frecuencias
# Out:
#     Edad  Frecuencia  Frecuencia Relativa  Frec. Porcentual  Frec. Acumulada
# 22    18           2                 0.02               2.0                2
# 18    19           2                 0.02               2.0                4
# 0     20           6                 0.06               6.0               10
# 12    21           3                 0.03               3.0               13
# 13    22           3                 0.03               3.0               16
# 24    23           2                 0.02               2.0               18
# 34    24           1                 0.01               1.0               19
# 47    25           1                 0.01               1.0               20
# 14    26           3                 0.03               3.0               23
# 6     27           3                 0.03               3.0               26
# 9     28           3                 0.03               3.0               29
# 32    29           1                 0.01               1.0               30
# 28    30           2                 0.02               2.0               32
# 45    31           1                 0.01               1.0               33
# 26    32           2                 0.02               2.0               35
# 23    35           2                 0.02               2.0               37
# 43    36           1                 0.01               1.0               38
# 41    37           1                 0.01               1.0               39
# 25    38           2                 0.02               2.0               41
# 37    39           1                 0.01               1.0               42
# 5     40           3                 0.03               3.0               45
# 40    41           1                 0.01               1.0               46
# 38    42           1                 0.01               1.0               47
# 29    43           2                 0.02               2.0               49
# 39    44           1                 0.01               1.0               50
# 2     45           4                 0.04               4.0               54
# 21    46           2                 0.02               2.0               56
# 16    48           2                 0.02               2.0               58
# 35    49           1                 0.01               1.0               59
# 15    50           2                 0.02               2.0               61
# 33    51           1                 0.01               1.0               62
# 46    52           1                 0.01               1.0               63
# 44    53           1                 0.01               1.0               64
# 19    54           2                 0.02               2.0               66
# 4     55           3                 0.03               3.0               69
# 1     56           4                 0.04               4.0               73
# 31    57           1                 0.01               1.0               74
# 17    58           2                 0.02               2.0               76
# 7     60           3                 0.03               3.0               79
# 10    61           3                 0.03               3.0               82
# 20    62           2                 0.02               2.0               84
# 42    63           1                 0.01               1.0               85
# 3     65           4                 0.04               4.0               89
# 36    66           1                 0.01               1.0               90
# 27    67           2                 0.02               2.0               92
# 30    68           2                 0.02               2.0               94
# 11    69           3                 0.03               3.0               97
# 8     70           3                 0.03               3.0              100

# %%
import math

# %%
print(edades)
# Out:
# [46, 27, 60, 18, 65, 50, 56, 55, 62, 58, 19, 54, 20, 45, 40, 48, 57, 26, 21, 21, 22, 20, 70, 19, 40, 68, 27, 35, 69, 38, 54, 66, 24, 49, 61, 50, 51, 26, 60, 27, 29, 45, 65, 23, 58, 44, 22, 32, 56, 20, 35, 22, 39, 38, 45, 62, 28, 61, 30, 42, 26, 43, 43, 41, 70, 40, 45, 55, 55, 37, 20, 67, 48, 63, 36, 68, 20, 69, 65, 23, 69, 53, 46, 70, 28, 21, 60, 28, 31, 61, 20, 32, 65, 56, 18, 30, 52, 56, 67, 25]

# %%
df=pd.DataFrame({'Edad': edades})
df
# Out:
#     Edad
# 0     46
# 1     27
# 2     60
# 3     18
# 4     65
# ..   ...
# 95    30
# 96    52
# 97    56
# 98    67
# 99    25
#
# [100 rows x 1 columns]

# %%
n=len(edades)
K=int(1+ math.log2(n))
print("Valor de n=", n, "\nNúmero de intervalos=", K)
# Out:
# Valor de n= 100
# Número de intervalos= 7

# %%
tabla_frecuencias= pd.cut(df['Edad'], bins=K, include_lowest=True).value_counts().reset_index()
tabla_frecuencias.columns=['Clase', 'Frecuencia']
tabla_frecuencias
# Out:
#               Clase  Frecuencia
# 0  (17.947, 25.429]          20
# 1    (62.571, 70.0]          16
# 2  (25.429, 32.857]          15
# 3  (55.143, 62.571]          15
# 4  (47.714, 55.143]          13
# 5  (40.286, 47.714]          11
# 6  (32.857, 40.286]          10

# %%
tabla_frecuencias= tabla_frecuencias.sort_values(by='Clase')
tabla_frecuencias
# Out:
#               Clase  Frecuencia
# 0  (17.947, 25.429]          20
# 2  (25.429, 32.857]          15
# 6  (32.857, 40.286]          10
# 5  (40.286, 47.714]          11
# 4  (47.714, 55.143]          13
# 3  (55.143, 62.571]          15
# 1    (62.571, 70.0]          16

# %%
tabla_frecuencias['Frecuencia Relativa'] = tabla_frecuencias['Frecuencia'] / n
tabla_frecuencias['Frec Porcentual'] = tabla_frecuencias ['Frecuencia'] / n * 100
tabla_frecuencias['Frec Acumulada'] = tabla_frecuencias['Frecuencia']. cumsum ()
tabla_frecuencias['Frec Rel Ac'] = tabla_frecuencias['Frecuencia Relativa']. cumsum ()
tabla_frecuencias['Frec Porc Ac'] = tabla_frecuencias['Frec Porcentual'].cumsum()

print(tabla_frecuencias)
# Out:
#               Clase  Frecuencia  Frecuencia Relativa  Frec Porcentual  \
# 0  (17.947, 25.429]          20                 0.20             20.0
# 2  (25.429, 32.857]          15                 0.15             15.0
# 6  (32.857, 40.286]          10                 0.10             10.0
# 5  (40.286, 47.714]          11                 0.11             11.0
# 4  (47.714, 55.143]          13                 0.13             13.0
# 3  (55.143, 62.571]          15                 0.15             15.0
# 1    (62.571, 70.0]          16                 0.16             16.0
#
#    Frec Acumulada  Frecuencia Rel Ac  Frec Porc Ac  Frec Rel Ac
# 0              20               0.20          20.0         0.20
# 2              35               0.35          35.0         0.35
# 6              45               0.45          45.0         0.45
# 5              56               0.56          56.0         0.56
# 4              69               0.69          69.0         0.69
# 3              84               0.84          84.0         0.84
# 1             100               1.00         100.0         1.00

# %%
import matplotlib.pyplot as plt
plt.hist(edades, alpha=0.5)
plt.title("Histograma de edades basado en la función de matplotlib con valores estandar")
# Out:
# Text(0.5, 1.0, 'Histograma de edades basado en la función de matplotlib con valores estandar')

# %%
plt.hist(df[ 'Edad'], bins=K, alpha = 0.5)
plt.title( 'Histograma de edades basado en la regla de Sturges')
plt.xlabel( 'Edades' )
plt.ylabel ('Frecuencia')
# Out:
# Text(0, 0.5, 'Frecuencia')
