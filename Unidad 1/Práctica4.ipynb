# %% [markdown]
# <a href="https://colab.research.google.com/github/ivethsg/Probabilidad-/blob/main/Unidad%201/Pr%C3%A1ctica4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Unidad 1
# ### Facilitador:  Dr. Jose Gabriel Rodriguez Rivas
# ### Alumno: Iveth Esperanza Santacruz Guerrero
# ### **Práctica 4: Diagrama de cajas y bigotes**

# %%
import random
import matplotlib.pyplot as plt
from statistics import *

# %%
fabrica1=[]
for i in range(100):
  numero_aleatorio= round(random.uniform(50,100),2)
  fabrica1.append(numero_aleatorio)
print(fabrica1)
# Out:
# [53.58, 77.82, 87.73, 62.07, 98.17, 90.62, 50.39, 67.02, 89.33, 83.7, 59.44, 68.94, 87.33, 57.54, 54.83, 80.53, 73.15, 56.38, 56.25, 89.67, 90.53, 55.34, 61.61, 56.71, 60.42, 52.76, 77.32, 63.04, 99.41, 70.54, 85.41, 52.06, 79.08, 86.14, 95.22, 51.39, 84.04, 92.51, 58.04, 88.73, 73.77, 95.26, 63.84, 87.52, 87.6, 79.04, 99.53, 91.68, 67.42, 57.45, 93.49, 60.75, 81.94, 77.34, 78.85, 88.39, 57.42, 68.5, 52.34, 88.56, 89.45, 63.12, 55.47, 59.52, 60.76, 84.15, 57.53, 61.24, 51.42, 56.88, 51.7, 89.39, 58.94, 61.5, 94.87, 97.12, 82.61, 58.98, 69.31, 69.07, 55.78, 80.26, 67.75, 63.04, 68.38, 88.92, 50.91, 91.1, 52.23, 64.5, 83.38, 60.67, 53.66, 69.8, 91.86, 70.07, 70.86, 54.93, 57.99, 50.82]

# %%
fabrica2=[]
for i in range(100):
  numero_aleatorio= round(random.uniform(40,93),2)
  fabrica2.append(numero_aleatorio)
print(fabrica2)
# Out:
# [62.37, 50.76, 66.36, 77.49, 87.8, 74.98, 75.97, 64.38, 78.08, 66.98, 47.96, 63.29, 55.58, 51.52, 51.98, 79.53, 55.46, 51.61, 85.87, 53.11, 88.3, 89.95, 59.23, 58.03, 57.56, 78.52, 68.67, 64.06, 57.6, 48.85, 81.84, 81.18, 69.1, 42.88, 50.79, 65.99, 50.61, 55.55, 53.4, 58.98, 66.47, 54.51, 69.77, 73.28, 87.35, 68.08, 42.41, 85.19, 59.39, 89.46, 67.48, 81.24, 45.22, 43.73, 59.18, 70.09, 64.74, 41.96, 65.35, 44.0, 58.87, 59.97, 57.13, 84.71, 48.72, 45.2, 47.32, 41.65, 52.92, 53.98, 71.24, 83.82, 70.9, 75.86, 46.63, 91.28, 47.48, 84.81, 85.21, 47.59, 55.24, 44.1, 46.78, 56.57, 42.34, 82.5, 54.91, 75.21, 64.26, 83.46, 65.7, 47.86, 86.73, 79.54, 71.23, 40.31, 90.33, 45.35, 63.35, 56.14]

# %%
plt.boxplot(fabrica1)
plt.ylabel('Producción en mts.')
plt.title('Producción en la fábrica 1')
plt.show()

# %%
fig, (ax1, ax2) = plt. subplots(nrows=1, ncols=2, figsize=(9, 4))
bplot1 = ax1. boxplot(fabrica1,
        vert=True,
        patch_artist=True)
ax1. set_title('Producción fabrica 1')

bplot2 = ax2. boxplot(fabrica2,
vert=True,
patch_artist=True)
ax2. set_title('Producción fabrica 2')
plt. show()

# %%
fabrica1.append(150)
print(fabrica1)
# Out:
# [53.58, 77.82, 87.73, 62.07, 98.17, 90.62, 50.39, 67.02, 89.33, 83.7, 59.44, 68.94, 87.33, 57.54, 54.83, 80.53, 73.15, 56.38, 56.25, 89.67, 90.53, 55.34, 61.61, 56.71, 60.42, 52.76, 77.32, 63.04, 99.41, 70.54, 85.41, 52.06, 79.08, 86.14, 95.22, 51.39, 84.04, 92.51, 58.04, 88.73, 73.77, 95.26, 63.84, 87.52, 87.6, 79.04, 99.53, 91.68, 67.42, 57.45, 93.49, 60.75, 81.94, 77.34, 78.85, 88.39, 57.42, 68.5, 52.34, 88.56, 89.45, 63.12, 55.47, 59.52, 60.76, 84.15, 57.53, 61.24, 51.42, 56.88, 51.7, 89.39, 58.94, 61.5, 94.87, 97.12, 82.61, 58.98, 69.31, 69.07, 55.78, 80.26, 67.75, 63.04, 68.38, 88.92, 50.91, 91.1, 52.23, 64.5, 83.38, 60.67, 53.66, 69.8, 91.86, 70.07, 70.86, 54.93, 57.99, 50.82, 150]

# %%
fig, (ax1, ax2) = plt. subplots(nrows=1, ncols=2, figsize=(9, 4))
bplot1 = ax1. boxplot(fabrica1,
        vert=True,
        patch_artist=True)
ax1. set_title('Producción fabrica 1')

bplot2 = ax2. boxplot(fabrica2,
vert=True,
patch_artist=True)
ax2. set_title('Producción fabrica 2')
plt. show()

# %%
fig, (ax1, ax2) = plt. subplots(nrows=1, ncols=2, figsize=(9, 4))
bplot1 = ax1. boxplot(fabrica1,
        vert=True,
        patch_artist=True)
ax1. set_title('Producción fabrica 1')
ax1.set_ylim(30,160)

bplot2 = ax2. boxplot(fabrica2,
vert=True,
patch_artist=True)
ax2. set_title('Producción fabrica 2')
ax1.set_ylim(30,160)

plt. show()
